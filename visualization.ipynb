# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('all_data.csv')

# %%
df['Rate'].hist(range=(0,15))
plt.savefig('rate_distribution.png')

# %%
df['Rate'].describe()
# Out:
# count    612.000000
# mean       3.041503
# std        2.089913
# min        0.000000
# 25%        1.500000
# 50%        2.500000
# 75%        4.000000
# max       14.300000
# Name: Rate, dtype: float64

# %%
import seaborn as sns; sns.set()
g = sns.PairGrid(df[['cough','TB','Rate']])
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6)
plt.savefig('kde_pairplot.png')
